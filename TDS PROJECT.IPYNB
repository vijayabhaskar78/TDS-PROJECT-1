# %%
import requests
import pandas as pd
import time
from urllib3.util import Retry
from requests.adapters import HTTPAdapter

# GitHub API Token (replace with your actual token)
api_token = 'Personal GitHub API will not allow if pasted here. Please replace with your own token.'  

# GitHub API URL and Headers
base_url = 'https://api.github.com'
headers = {
    'Authorization': f'token {api_token}',
    'Accept': 'application/vnd.github.v3+json'  # Added explicit API version
}

# Initialize retry strategy and session for requests
try:
    retry_strategy = Retry(
        total=3,
        backoff_factor=1,
        status_forcelist=[429, 500, 502, 503, 504]
    )
    session = requests.Session()
    session.mount("https://", HTTPAdapter(max_retries=retry_strategy))
except Exception as e:
    print(f"Error setting up retry strategy: {e}")
    print("Continuing without retry mechanism...")
    session = requests.Session()

# Function to handle GitHub API rate limiting
def handle_rate_limiting(response):
    if response.status_code == 403 and "X-RateLimit-Remaining" in response.headers:
        if int(response.headers["X-RateLimit-Remaining"]) == 0:
            reset_time = int(response.headers["X-RateLimit-Reset"])
            sleep_time = reset_time - int(time.time())
            print(f"Rate limit exceeded. Sleeping for {sleep_time} seconds.")
            time.sleep(sleep_time)
            return True
    return False

# Collect users with location 'Shanghai' and followers >= 200
users_data = []
page = 1
while True:
    users_url = f"{base_url}/search/users?q=location:Shanghai+followers:>=200&page={page}&per_page=100"
    try:
        response = session.get(users_url, headers=headers)
        response.raise_for_status()  # Added error checking
        if handle_rate_limiting(response):
            continue
        data = response.json()
        if 'items' not in data or not data['items']:
            break
        users_data.extend(data['items'])
        page += 1
        print(f"Fetched page {page} of users")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching users page {page}: {e}")
        if page > 1:  # If we have some data, continue with processing
            break
        else:
            raise  # If we have no data at all, raise the error

# Extract detailed user information
users = []
for i, user in enumerate(users_data, 1):
    try:
        user_detail_url = user['url']
        user_response = session.get(user_detail_url, headers=headers)
        user_response.raise_for_status()
        if handle_rate_limiting(user_response):
            continue
        user_info = user_response.json()

        # Clean up company name as per requirements
        company = user_info.get('company', '')
        if company:
            company = company.strip().lstrip('@').upper()

        users.append({
            'login': user_info['login'],
            'name': user_info.get('name'),
            'company': company,
            'location': user_info.get('location'),
            'email': user_info.get('email'),
            'hireable': 'true' if user_info.get('hireable') else 'false',
            'bio': user_info.get('bio'),
            'public_repos': user_info.get('public_repos'),
            'followers': user_info.get('followers'),
            'following': user_info.get('following'),
            'created_at': user_info.get('created_at')
        })
        print(f"Processed user {i} of {len(users_data)}: {user_info['login']}")
    except requests.exceptions.RequestException as e:
        print(f"Error processing user {user.get('login', 'unknown')}: {e}")
        continue

# Convert user data to DataFrame and save as CSV
users_df = pd.DataFrame(users)
users_df.to_csv('users.csv', index=False)

# Fetch repositories for each user, limited to 500 most recently pushed repos per user
repos = []
for i, user in enumerate(users, 1):
    page = 1
    user_repos = []
    print(f"Fetching repositories for user {i} of {len(users)}: {user['login']}")
    
    while True:
        try:
            repos_url = f"{base_url}/users/{user['login']}/repos?sort=pushed&direction=desc&page={page}&per_page=100"
            repos_response = session.get(repos_url, headers=headers)
            repos_response.raise_for_status()
            if handle_rate_limiting(repos_response):
                continue
            repos_data = repos_response.json()
            if not repos_data or len(user_repos) >= 500:
                break
                
            for repo in repos_data:
                if len(user_repos) >= 500:
                    break
                user_repos.append({
                    'login': user['login'],
                    'full_name': repo['full_name'],
                    'created_at': repo['created_at'],
                    'stargazers_count': repo['stargazers_count'],
                    'watchers_count': repo['watchers_count'],
                    'language': repo['language'],
                    'has_projects': 'true' if repo['has_projects'] else 'false',
                    'has_wiki': 'true' if repo['has_wiki'] else 'false',
                    'license_name': repo['license']['name'] if repo['license'] else ''
                })
            page += 1
        except requests.exceptions.RequestException as e:
            print(f"Error fetching repositories for user {user['login']} page {page}: {e}")
            break
        
    repos.extend(user_repos)
    print(f"Fetched {len(user_repos)} repositories for {user['login']}")

# Convert repository data to DataFrame and save as CSV
repos_df = pd.DataFrame(repos)
repos_df.to_csv('repositories.csv', index=False)

print("\nData scraping completed successfully!")
print(f"Total users scraped: {len(users)}")
print(f"Total repositories scraped: {len(repos)}")
# Out:
# Fetched page 2 of users
# Fetched page 3 of users
# Fetched page 4 of users
# Fetched page 5 of users
# Fetched page 6 of users
# Fetched page 7 of users
# Fetched page 8 of users
# Fetched page 9 of users
# Processed user 1 of 744: peng-zhihui
# Processed user 2 of 744: ruanyf
# Processed user 3 of 744: phodal
# Processed user 4 of 744: liyupi
# Processed user 5 of 744: stormzhang
# Processed user 6 of 744: Ovilia
# Processed user 7 of 744: astaxie
# Processed user 8 of 744: bailicangdu
# Processed user 9 of 744: PanJiaChen
# Processed user 10 of 744: YunaiV
# Processed user 11 of 744: sofish
# Processed user 12 of 744: dyc87112
# Processed user 13 of 744: skyzh
# Processed user 14 of 744: nihui
# Processed user 15 of 744: oldratlee
# Processed user 16 of 744: xufei
# Processed user 17 of 744: amusi
# Processed user 18 of 744: TommyZihao
# Processed user 19 of 744: xuxueli
# Processed user 20 of 744: wx-chevalier
# Processed user 21 of 744: krahets
# Processed user 22 of 744: teddysun
# Processed user 23 of 744: hellokaton
# Processed user 24 of 744: espressif
# Processed user 25 of 744: madeye
# Processed user 26 of 744: hax
# Processed user 27 of 744: pissang
# Processed user 28 of 744: kesenhoo
# Processed user 29 of 744: jmzeng1314
# Processed user 30 of 744: yiminghe
# Processed user 31 of 744: code4craft
# Processed user 32 of 744: lexrus
# Processed user 33 of 744: casatwy
# Processed user 34 of 744: xpqiu
# Processed user 35 of 744: markzhai
# Processed user 36 of 744: candycat1992
# Processed user 37 of 744: matyhtf
# Processed user 38 of 744: Justineo
# Processed user 39 of 744: gsdios
# Processed user 40 of 744: binjie09
# Processed user 41 of 744: GcsSloop
# Processed user 42 of 744: Ewenwan
# Processed user 43 of 744: KittenYang
# Processed user 44 of 744: kymjs
# Processed user 45 of 744: sl1673495
# Processed user 46 of 744: vnpy
# Processed user 47 of 744: formulahendry
# Processed user 48 of 744: tiye
# Processed user 49 of 744: Skykai521
# Processed user 50 of 744: feiskyer
# Processed user 51 of 744: greyli
# Processed user 52 of 744: geektutu
# Processed user 53 of 744: Lucifier129
# Processed user 54 of 744: archibate
# Processed user 55 of 744: zzz40500
# Processed user 56 of 744: VincentWong3
# Processed user 57 of 744: mmin18
# Processed user 58 of 744: DjangoPeng
# Processed user 59 of 744: Vamei
# Processed user 60 of 744: wong2
# Processed user 61 of 744: shidenggui
# Processed user 62 of 744: bilibili
# Processed user 63 of 744: island205
# Processed user 64 of 744: armink
# Processed user 65 of 744: igrr
# Processed user 66 of 744: xuyisheng
# Processed user 67 of 744: MaxwellGengYF
# Processed user 68 of 744: iamkun
# Processed user 69 of 744: uknowsec
# Processed user 70 of 744: davideuler
# Processed user 71 of 744: Jannchie
# Processed user 72 of 744: ctiao
# Processed user 73 of 744: begeekmyfriend
# Processed user 74 of 744: kuitos
# Processed user 75 of 744: FrozenGene
# Processed user 76 of 744: yc9559
# Processed user 77 of 744: qii
# Processed user 78 of 744: csvwolf
# Processed user 79 of 744: CymChad
# Processed user 80 of 744: yisar
# Processed user 81 of 744: ihciah
# Processed user 82 of 744: electech6
# Processed user 83 of 744: BaronZ88
# Processed user 84 of 744: Charmve
# Processed user 85 of 744: XINCGer
# Processed user 86 of 744: LeoMobileDeveloper
# Processed user 87 of 744: losfair
# Processed user 88 of 744: knightliao
# Processed user 89 of 744: lychees
# Processed user 90 of 744: GoSSIP-SJTU
# Processed user 91 of 744: EspressifApp
# Processed user 92 of 744: cyfdecyf
# Processed user 93 of 744: songquanpeng
# Processed user 94 of 744: zombieJ
# Processed user 95 of 744: shrekshrek
# Processed user 96 of 744: ExpLangcn
# Processed user 97 of 744: lightningMan
# Processed user 98 of 744: houbb
# Processed user 99 of 744: liu21st
# Processed user 100 of 744: wnzhang
# Processed user 101 of 744: jikeytang
# Processed user 102 of 744: xiewenwei
# Processed user 103 of 744: zensh
# Processed user 104 of 744: cfc4n
# Processed user 105 of 744: nobodyiam
# Processed user 106 of 744: KeKe-Li
# Processed user 107 of 744: journey-ad
# Processed user 108 of 744: Jocs
# Processed user 109 of 744: mcxtzhang
# Processed user 110 of 744: wingjay
# Processed user 111 of 744: leeight
# Processed user 112 of 744: fordream
# Processed user 113 of 744: zhuangbiaowei
# Processed user 114 of 744: flyerhzm
# Processed user 115 of 744: Becavalier
# Processed user 116 of 744: yangxue0827
# Processed user 117 of 744: cipchk
# Processed user 118 of 744: dsh0416
# Processed user 119 of 744: aksnzhy
# Processed user 120 of 744: linyiqun
# Processed user 121 of 744: levey
# Processed user 122 of 744: caesar0301
# Processed user 123 of 744: mashirozx
# Processed user 124 of 744: aozhimin
# Processed user 125 of 744: r0eXpeR
# Processed user 126 of 744: z-song
# Processed user 127 of 744: feifeibear
# Processed user 128 of 744: unix
# Processed user 129 of 744: kaleai
# Processed user 130 of 744: zhouguangming
# Processed user 131 of 744: hzy46
# Processed user 132 of 744: SeuTao
# Processed user 133 of 744: AlexV525
# Processed user 134 of 744: supnate
# Processed user 135 of 744: manageyp
# Processed user 136 of 744: RangiLyu
# Processed user 137 of 744: hit9
# Processed user 138 of 744: DavidCai1111
# Processed user 139 of 744: robbin
# Processed user 140 of 744: otakustay
# Processed user 141 of 744: EYHN
# Processed user 142 of 744: netcan
# Processed user 143 of 744: loody
# Processed user 144 of 744: jdneo
# Processed user 145 of 744: yinjihuan
# Processed user 146 of 744: ma6174
# Processed user 147 of 744: tanjiti
# Processed user 148 of 744: BernardXiong
# Processed user 149 of 744: Doraemonzzz
# Processed user 150 of 744: JeasonWong
# Processed user 151 of 744: MuYunyun
# Processed user 152 of 744: wuhan005
# Processed user 153 of 744: Leopoldthecoder
# Processed user 154 of 744: jkchao
# Processed user 155 of 744: xen0n
# Processed user 156 of 744: laobie
# Processed user 157 of 744: taoso
# Processed user 158 of 744: renkun-ken
# Processed user 159 of 744: ElemeFE
# Processed user 160 of 744: andyzhangx
# Processed user 161 of 744: ZigaoWang
# Processed user 162 of 744: lietoumai
# Processed user 163 of 744: yixuan
# Processed user 164 of 744: jamesge
# Processed user 165 of 744: lotabout
# Processed user 166 of 744: breezewish
# Processed user 167 of 744: hetong007
# Processed user 168 of 744: kingname
# Processed user 169 of 744: MegatronKing
# Processed user 170 of 744: tonybase
# Processed user 171 of 744: tinyfool
# Processed user 172 of 744: JJYing
# Processed user 173 of 744: lni
# Processed user 174 of 744: Jinxiansen
# Processed user 175 of 744: PhotonQuantum
# Processed user 176 of 744: GeekLiB
# Processed user 177 of 744: ginuerzh
# Processed user 178 of 744: ltebean
# Processed user 179 of 744: sun0225SUN
# Processed user 180 of 744: Sneezry
# Processed user 181 of 744: sisterAn
# Processed user 182 of 744: sunniejs
# Processed user 183 of 744: qiankanglai
# Processed user 184 of 744: erning
# Processed user 185 of 744: ithewei
# Processed user 186 of 744: adah1972
# Processed user 187 of 744: Enter-tainer
# Processed user 188 of 744: Frank-Zhu
# Processed user 189 of 744: jerrykuku
# Processed user 190 of 744: wey-gu
# Processed user 191 of 744: ShenQingchuan
# Processed user 192 of 744: kitelife
# Processed user 193 of 744: jkzing
# Processed user 194 of 744: billryan
# Processed user 195 of 744: godweiyang
# Processed user 196 of 744: seedante
# Processed user 197 of 744: skyvow
# Processed user 198 of 744: cubercsl
# Processed user 199 of 744: NELSONZHAO
# Processed user 200 of 744: AnoyiX
# Processed user 201 of 744: hawkingrei
# Processed user 202 of 744: ElderJames
# Processed user 203 of 744: vikingmute
# Processed user 204 of 744: endymecy
# Processed user 205 of 744: creeperyang
# Processed user 206 of 744: WenmuZhou
# Processed user 207 of 744: AlloVince
# Processed user 208 of 744: XVilka
# Processed user 209 of 744: allenhsu
# Processed user 210 of 744: jobbole
# Processed user 211 of 744: ArthurChiao
# Processed user 212 of 744: junqiangchen
# Processed user 213 of 744: txsun1997
# Processed user 214 of 744: desmond1121
# Processed user 215 of 744: LeetCode-China
# Processed user 216 of 744: pacoxu
# Processed user 217 of 744: army8735
# Processed user 218 of 744: dastagir-ahmed
# Processed user 219 of 744: Sanster
# Processed user 220 of 744: xupsh
# Processed user 221 of 744: nb312
# Processed user 222 of 744: ethanhua
# Processed user 223 of 744: SJTU-IPADS
# Processed user 224 of 744: Simon-He95
# Processed user 225 of 744: luikore
# Processed user 226 of 744: moesoha
# Processed user 227 of 744: vvpvvp
# Processed user 228 of 744: PureWhiteWu
# Processed user 229 of 744: langgithub
# Processed user 230 of 744: SimonZhangITer
# Processed user 231 of 744: oovm
# Processed user 232 of 744: stone-zeng
# Processed user 233 of 744: ciaochaos
# Processed user 234 of 744: rainyear
# Processed user 235 of 744: gxcsoccer
# Processed user 236 of 744: ZhouYixun
# Processed user 237 of 744: mmoaay
# Processed user 238 of 744: LangziFun
# Processed user 239 of 744: fengzhizi715
# Processed user 240 of 744: AAChartModel
# Processed user 241 of 744: giraffe0813
# Processed user 242 of 744: zengyh1900
# Processed user 243 of 744: gaussic
# Processed user 244 of 744: yulunzhang
# Processed user 245 of 744: Doragd
# Processed user 246 of 744: wayslog
# Processed user 247 of 744: whai362
# Processed user 248 of 744: chanjarster
# Processed user 249 of 744: dkmeteor
# Processed user 250 of 744: MengRao
# Processed user 251 of 744: barry-ran
# Processed user 252 of 744: bettenW
# Processed user 253 of 744: CreditTone
# Processed user 254 of 744: Thinklab-SJTU
# Processed user 255 of 744: mzz2017
# Processed user 256 of 744: cooelf
# Processed user 257 of 744: linlinjava
# Processed user 258 of 744: cofyc
# Processed user 259 of 744: hhstore
# Processed user 260 of 744: huailiang
# Processed user 261 of 744: PytLab
# Processed user 262 of 744: qmwu2000
# Processed user 263 of 744: softwind0214
# Processed user 264 of 744: osteele
# Processed user 265 of 744: jackeyGao
# Processed user 266 of 744: ElegantLaTeX
# Processed user 267 of 744: zry656565
# Processed user 268 of 744: WeihanLi
# Processed user 269 of 744: heibaiying
# Processed user 270 of 744: litaotao
# Processed user 271 of 744: Tamicer
# Processed user 272 of 744: foamliu
# Processed user 273 of 744: frankdevhub
# Processed user 274 of 744: LittleSound
# Processed user 275 of 744: yangzhe1991
# Processed user 276 of 744: w446108264
# Processed user 277 of 744: wangyasai
# Processed user 278 of 744: chinese-poetry
# Processed user 279 of 744: CodeSama346623
# Processed user 280 of 744: zmmbreeze
# Processed user 281 of 744: shalldie
# Processed user 282 of 744: Hzfengsy
# Processed user 283 of 744: panghaijiao
# Processed user 284 of 744: alexinea
# Processed user 285 of 744: BolexLiu
# Processed user 286 of 744: DCjanus
# Processed user 287 of 744: cubxxw
# Processed user 288 of 744: jagt
# Processed user 289 of 744: celeron533
# Processed user 290 of 744: qq547276542
# Processed user 291 of 744: nttstar
# Processed user 292 of 744: xiandanin
# Processed user 293 of 744: madneal
# Processed user 294 of 744: zhanwen
# Processed user 295 of 744: why404
# Processed user 296 of 744: yanghua
# Processed user 297 of 744: jokermonn
# Processed user 298 of 744: dfguo
# Processed user 299 of 744: JackonYang
# Processed user 300 of 744: lifeiteng
# Processed user 301 of 744: qiyuangong
# Processed user 302 of 744: shadowcz007
# Processed user 303 of 744: bxm0927
# Processed user 304 of 744: nanxiaobei
# Processed user 305 of 744: yangminz
# Processed user 306 of 744: hackerzhou
# Processed user 307 of 744: TianLin0509
# Processed user 308 of 744: Teaonly
# Processed user 309 of 744: mrluanma
# Processed user 310 of 744: fffonion
# Processed user 311 of 744: percent4
# Processed user 312 of 744: linexjlin
# Processed user 313 of 744: wzhudev
# Processed user 314 of 744: daxnet
# Processed user 315 of 744: hnes
# Processed user 316 of 744: QiShaoXuan
# Processed user 317 of 744: MoZhouqi
# Processed user 318 of 744: nimoc
# Processed user 319 of 744: lkml-likexu
# Processed user 320 of 744: LuckSiege
# Processed user 321 of 744: hli2020
# Processed user 322 of 744: chenxuuu
# Processed user 323 of 744: yuzd
# Processed user 324 of 744: Moriadry-zz
# Processed user 325 of 744: undefined-moe
# Processed user 326 of 744: yanyongyu
# Processed user 327 of 744: Leifzhang
# Processed user 328 of 744: makeapp
# Processed user 329 of 744: jasonross
# Processed user 330 of 744: Jeff-sjtu
# Processed user 331 of 744: ghosert
# Processed user 332 of 744: philcn
# Processed user 333 of 744: goddyZhao
# Processed user 334 of 744: h-a-n-a
# Processed user 335 of 744: ShiningRay
# Processed user 336 of 744: Kyle-Ye
# Processed user 337 of 744: Sorosliu1029
# Processed user 338 of 744: zhuwenxing
# Processed user 339 of 744: youjiali1995
# Processed user 340 of 744: zthxxx
# Processed user 341 of 744: SuneBear
# Processed user 342 of 744: Garfield550
# Processed user 343 of 744: u-u-z
# Processed user 344 of 744: DreamWaterFound
# Processed user 345 of 744: tangyouhua
# Processed user 346 of 744: h4ckdepy
# Processed user 347 of 744: shiyunbo
# Processed user 348 of 744: tchaikov
# Processed user 349 of 744: luciouskami
# Processed user 350 of 744: meiqua
# Processed user 351 of 744: changsanjiang
# Processed user 352 of 744: lygttpod
# Processed user 353 of 744: sangmingming
# Processed user 354 of 744: tony612
# Processed user 355 of 744: livc
# Processed user 356 of 744: hylarucoder
# Processed user 357 of 744: amorist
# Processed user 358 of 744: oa414
# Processed user 359 of 744: shixinzhang
# Processed user 360 of 744: lightszero
# Processed user 361 of 744: yimengfan
# Processed user 362 of 744: johnnychen94
# Processed user 363 of 744: DirtyHarryLYL
# Processed user 364 of 744: archbobo
# Processed user 365 of 744: ottomao
# Processed user 366 of 744: openproject
# Processed user 367 of 744: oneinstack
# Processed user 368 of 744: Tamsiree
# Processed user 369 of 744: raoenhui
# Processed user 370 of 744: haoxins
# Processed user 371 of 744: sequoiar
# Processed user 372 of 744: wangdahoo
# Processed user 373 of 744: mc-zone
# Processed user 374 of 744: lijinma
# Processed user 375 of 744: SuperSodaSea
# Processed user 376 of 744: rainux
# Processed user 377 of 744: erikzhang
# Processed user 378 of 744: FXTD-ODYSSEY
# Processed user 379 of 744: ai-winter
# Processed user 380 of 744: Omooo
# Processed user 381 of 744: dixudx
# Processed user 382 of 744: orca-zhang
# Processed user 383 of 744: mzule
# Processed user 384 of 744: downdemo
# Processed user 385 of 744: Linzaer
# Processed user 386 of 744: youngfish42
# Processed user 387 of 744: zhenrong-wang
# Processed user 388 of 744: changmingxie
# Processed user 389 of 744: Tedko
# Processed user 390 of 744: SteNicholas
# Processed user 391 of 744: yeahx
# Processed user 392 of 744: im0qianqian
# Processed user 393 of 744: eson15
# Processed user 394 of 744: JaredTan95
# Processed user 395 of 744: peterzheng98
# Processed user 396 of 744: ErosZy
# Processed user 397 of 744: hzh0425
# Processed user 398 of 744: HaojunRen
# Processed user 399 of 744: ctripcorp
# Processed user 400 of 744: xiangsx
# Processed user 401 of 744: marywangran
# Processed user 402 of 744: Sitoi
# Processed user 403 of 744: AirGuanZ
# Processed user 404 of 744: langyo
# Processed user 405 of 744: wxs77577
# Processed user 406 of 744: tyshiwo
# Processed user 407 of 744: netpi
# Processed user 408 of 744: netwarm007
# Processed user 409 of 744: josephzhang23
# Processed user 410 of 744: owent
# Processed user 411 of 744: austinhuang0131
# Processed user 412 of 744: LeetCode-OpenSource
# Processed user 413 of 744: kpzhang93
# Processed user 414 of 744: waderwu
# Processed user 415 of 744: tpoisonooo
# Processed user 416 of 744: 8enet
# Processed user 417 of 744: lework
# Processed user 418 of 744: Rhilip
# Processed user 419 of 744: ecomfe
# Processed user 420 of 744: LuckyZXL2016
# Processed user 421 of 744: Artoria2e5
# Processed user 422 of 744: CeuiLiSA
# Processed user 423 of 744: Lax
# Processed user 424 of 744: leftthomas
# Processed user 425 of 744: mfanjie
# Processed user 426 of 744: lealife
# Processed user 427 of 744: hiddenzzh
# Processed user 428 of 744: Kyson
# Processed user 429 of 744: wolfogre
# Processed user 430 of 744: ichn-hu
# Processed user 431 of 744: hanxiaomax
# Processed user 432 of 744: baowenbo
# Processed user 433 of 744: xxjwxc
# Processed user 434 of 744: SeanLee97
# Processed user 435 of 744: zsummer
# Processed user 436 of 744: wenfangdu
# Processed user 437 of 744: kittencup
# Processed user 438 of 744: apanly
# Processed user 439 of 744: lovelyyoshino
# Processed user 440 of 744: smallpath
# Processed user 441 of 744: smallsnail-wh
# Processed user 442 of 744: KexyBiscuit
# Processed user 443 of 744: starnightcyber
# Processed user 444 of 744: peterjc123
# Processed user 445 of 744: simonguo
# Processed user 446 of 744: liuwons
# Processed user 447 of 744: xubinux
# Processed user 448 of 744: jijiechen
# Processed user 449 of 744: grissomsh
# Processed user 450 of 744: imClumsyPanda
# Processed user 451 of 744: yechaoa
# Processed user 452 of 744: clojurians-org
# Processed user 453 of 744: qddegtya
# Processed user 454 of 744: hughfenghen
# Processed user 455 of 744: x-hw
# Processed user 456 of 744: kalcaddle
# Processed user 457 of 744: laurentkneip
# Processed user 458 of 744: u3u
# Processed user 459 of 744: Yuan-ManX
# Processed user 460 of 744: alinxalinx
# Processed user 461 of 744: jzlxiaohei
# Processed user 462 of 744: objcoding
# Processed user 463 of 744: idootop
# Processed user 464 of 744: yyong119
# Processed user 465 of 744: dyng
# Processed user 466 of 744: classicemi
# Processed user 467 of 744: OpenGG
# Processed user 468 of 744: zhausong
# Processed user 469 of 744: JosephZhu1983
# Processed user 470 of 744: Miachol
# Processed user 471 of 744: JonyFang
# Processed user 472 of 744: guileen
# Processed user 473 of 744: wishstudio
# Processed user 474 of 744: polyrabbit
# Processed user 475 of 744: Aleafy
# Processed user 476 of 744: zhangyoufu
# Processed user 477 of 744: XiaoMiku01
# Processed user 478 of 744: TsingZ0
# Processed user 479 of 744: sjtug
# Processed user 480 of 744: AlexGeControl
# Processed user 481 of 744: zhangxiaoyu-zidif
# Processed user 482 of 744: yzhangcs
# Processed user 483 of 744: Evensgn
# Processed user 484 of 744: zh99998
# Processed user 485 of 744: ChinaQMTECH
# Processed user 486 of 744: Morizeyao
# Processed user 487 of 744: Penglai-Enclave
# Processed user 488 of 744: voldikss
# Processed user 489 of 744: YanagiEiichi
# Processed user 490 of 744: Tai-Wang
# Processed user 491 of 744: Galaxies99
# Processed user 492 of 744: DequanWang
# Processed user 493 of 744: lxyu
# Processed user 494 of 744: KengoTODA
# Processed user 495 of 744: robopeak
# Processed user 496 of 744: AngelMonica126
# Processed user 497 of 744: nnhy
# Processed user 498 of 744: zhuweiyou
# Processed user 499 of 744: WalterInSH
# Processed user 500 of 744: ddadaal
# Processed user 501 of 744: wzmsltw
# Processed user 502 of 744: Moosphan
# Processed user 503 of 744: Yggdroot
# Processed user 504 of 744: xyjigsaw
# Processed user 505 of 744: haifengat
# Processed user 506 of 744: sijichun
# Processed user 507 of 744: KevinWang15
# Processed user 508 of 744: wdlhao
# Processed user 509 of 744: yaocccc
# Processed user 510 of 744: JinHai-CN
# Processed user 511 of 744: TencentYouTu
# Processed user 512 of 744: EBWi11
# Processed user 513 of 744: 599316527
# Processed user 514 of 744: kennymckormick
# Processed user 515 of 744: adrian-wang
# Processed user 516 of 744: gonnavis
# Processed user 517 of 744: hantmac
# Processed user 518 of 744: bcmi
# Processed user 519 of 744: ssthouse
# Processed user 520 of 744: vision4robotics
# Processed user 521 of 744: LiMeii
# Processed user 522 of 744: sjlleo
# Processed user 523 of 744: zslomo
# Processed user 524 of 744: bonfy
# Processed user 525 of 744: Kaijun
# Processed user 526 of 744: realJustinLee
# Processed user 527 of 744: oikomi
# Processed user 528 of 744: iChenLei
# Processed user 529 of 744: Stay
# Processed user 530 of 744: simonsmh
# Processed user 531 of 744: Paper-Pen
# Processed user 532 of 744: XinJingHao
# Processed user 533 of 744: liluo
# Processed user 534 of 744: mckelvin
# Processed user 535 of 744: lightory
# Processed user 536 of 744: 1357310795
# Processed user 537 of 744: nimengbo
# Processed user 538 of 744: MisakiKata
# Processed user 539 of 744: ingra14m
# Processed user 540 of 744: js-newbee
# Processed user 541 of 744: gumblex
# Processed user 542 of 744: tonysy
# Processed user 543 of 744: jin10086
# Processed user 544 of 744: caohuilin
# Processed user 545 of 744: caiyue1993
# Processed user 546 of 744: Lchiffon
# Processed user 547 of 744: hbb1
# Processed user 548 of 744: jxlwqq
# Processed user 549 of 744: penguin-wwy
# Processed user 550 of 744: b1gtang
# Processed user 551 of 744: jameslz
# Processed user 552 of 744: Zero-Tang
# Processed user 553 of 744: danping
# Processed user 554 of 744: doubledaibo
# Processed user 555 of 744: zjffdu
# Processed user 556 of 744: yiranran
# Processed user 557 of 744: liaojinxing
# Processed user 558 of 744: monadbobo
# Processed user 559 of 744: hegaojian
# Processed user 560 of 744: Knight-ZXW
# Processed user 561 of 744: heanxu
# Processed user 562 of 744: bolasblack
# Processed user 563 of 744: furybean
# Processed user 564 of 744: ShannonChenCHN
# Processed user 565 of 744: jjeffcaii
# Processed user 566 of 744: xfguo
# Processed user 567 of 744: ainilili
# Processed user 568 of 744: KevinOfNeu
# Processed user 569 of 744: leftstick
# Processed user 570 of 744: TencentYoutuResearch
# Processed user 571 of 744: JeffMony
# Processed user 572 of 744: water8394
# Processed user 573 of 744: turkyden
# Processed user 574 of 744: bloodycoder
# Processed user 575 of 744: Hengle
# Processed user 576 of 744: qitianwu
# Processed user 577 of 744: wangyum
# Processed user 578 of 744: chunhuajiang
# Processed user 579 of 744: sticnarf
# Processed user 580 of 744: dujiajun
# Processed user 581 of 744: Ashinch
# Processed user 582 of 744: jcf94
# Processed user 583 of 744: HoshinoTouko
# Processed user 584 of 744: wzshiming
# Processed user 585 of 744: dingxiaowei
# Processed user 586 of 744: undoZen
# Processed user 587 of 744: EspressifSystems
# Processed user 588 of 744: ningyu1
# Processed user 589 of 744: xujinyang
# Processed user 590 of 744: xyczero
# Processed user 591 of 744: GToad
# Processed user 592 of 744: longbai
# Processed user 593 of 744: j5s
# Processed user 594 of 744: MLEveryday
# Processed user 595 of 744: lxneng
# Processed user 596 of 744: LeoQ7
# Processed user 597 of 744: DeqianBai
# Processed user 598 of 744: hutusi
# Processed user 599 of 744: haoxianrui
# Processed user 600 of 744: yejianye
# Processed user 601 of 744: Chaphlagical
# Processed user 602 of 744: tatsuya6502
# Processed user 603 of 744: OceanPang
# Processed user 604 of 744: liyishuai
# Processed user 605 of 744: DiamondYuan
# Processed user 606 of 744: wgtdkp
# Processed user 607 of 744: CDog34
# Processed user 608 of 744: SevenOutman
# Processed user 609 of 744: ZhikangNiu
# Processed user 610 of 744: MxABC
# Processed user 611 of 744: reitowo
# Processed user 612 of 744: yingl
# Processed user 613 of 744: cnlinxi
# Processed user 614 of 744: noahcao
# Processed user 615 of 744: xalanq
# Processed user 616 of 744: dsdshcym
# Processed user 617 of 744: huxq17
# Processed user 618 of 744: Hzzone
# Processed user 619 of 744: TJ-CSCCG
# Processed user 620 of 744: CyrusF
# Processed user 621 of 744: dushibaiyu
# Processed user 622 of 744: Yang-Xijie
# Processed user 623 of 744: wenerme
# Processed user 624 of 744: lyfeyaj
# Processed user 625 of 744: jessetalk
# Processed user 626 of 744: jckling
# Processed user 627 of 744: Aaaaaaron
# Processed user 628 of 744: yumi0629
# Processed user 629 of 744: lmmsoft
# Processed user 630 of 744: macdao
# Processed user 631 of 744: ChenBohan
# Processed user 632 of 744: dong77
# Processed user 633 of 744: wangrui460
# Processed user 634 of 744: youjin255
# Processed user 635 of 744: pwxcoo
# Processed user 636 of 744: seognil
# Processed user 637 of 744: Aneureka
# Processed user 638 of 744: fyuanfen
# Processed user 639 of 744: dianping
# Processed user 640 of 744: Ahoo-Wang
# Processed user 641 of 744: dozer47528
# Processed user 642 of 744: liaogx
# Processed user 643 of 744: Singosgu
# Processed user 644 of 744: joyoyao
# Processed user 645 of 744: qianjiachun
# Processed user 646 of 744: kesalin
# Processed user 647 of 744: PanQiWei
# Processed user 648 of 744: eragonruan
# Processed user 649 of 744: elrrrrrrr
# Processed user 650 of 744: fudan-zvg
# Processed user 651 of 744: KSkun
# Processed user 652 of 744: chaoma99
# Processed user 653 of 744: coderZsq
# Processed user 654 of 744: njcx
# Processed user 655 of 744: zehuichen123
# Processed user 656 of 744: lwch
# Processed user 657 of 744: UxxHans
# Processed user 658 of 744: nanshihui
# Processed user 659 of 744: sunoj
# Processed user 660 of 744: taojy123
# Processed user 661 of 744: jimmykuu
# Processed user 662 of 744: BestDingSheng
# Processed user 663 of 744: 6boris
# Processed user 664 of 744: zcong1993
# Processed user 665 of 744: elliotxx
# Processed user 666 of 744: xiaoronglv
# Processed user 667 of 744: mahavivo
# Processed user 668 of 744: observerss
# Processed user 669 of 744: pibigstar
# Processed user 670 of 744: cs1ime
# Processed user 671 of 744: Fazziekey
# Processed user 672 of 744: jumper2014
# Processed user 673 of 744: Andy1621
# Processed user 674 of 744: DFRobot
# Processed user 675 of 744: iofu728
# Processed user 676 of 744: zhpanvip
# Processed user 677 of 744: lz1998
# Processed user 678 of 744: Anticorianderist
# Processed user 679 of 744: wzxha
# Processed user 680 of 744: sec-an
# Processed user 681 of 744: RevySR
# Processed user 682 of 744: adohe-zz
# Processed user 683 of 744: chenxuan0000
# Processed user 684 of 744: osgochina
# Processed user 685 of 744: geekwolf
# Processed user 686 of 744: zhiqiangxu
# Processed user 687 of 744: jasonGeng88
# Processed user 688 of 744: Maxwin-z
# Processed user 689 of 744: yongluo2013
# Processed user 690 of 744: liguobao
# Processed user 691 of 744: IFmiss
# Processed user 692 of 744: OysterQAQ
# Processed user 693 of 744: childrentime
# Processed user 694 of 744: sillykelvin
# Processed user 695 of 744: HillZhang1999
# Processed user 696 of 744: Lancern
# Processed user 697 of 744: wolf96
# Processed user 698 of 744: tashaxing
# Processed user 699 of 744: worldzhao
# Processed user 700 of 744: chenkkkk
# Processed user 701 of 744: felixhao
# Processed user 702 of 744: liangxiegame
# Processed user 703 of 744: soarqin
# Processed user 704 of 744: comzyh
# Processed user 705 of 744: Bywalks
# Processed user 706 of 744: YesianRohn
# Processed user 707 of 744: xdd666t
# Processed user 708 of 744: wegamekinglc
# Processed user 709 of 744: miclle
# Processed user 710 of 744: ultmaster
# Processed user 711 of 744: shyoshyo
# Processed user 712 of 744: waynebaby
# Processed user 713 of 744: xw-hu
# Processed user 714 of 744: EthanDeng
# Processed user 715 of 744: eshengsky
# Processed user 716 of 744: qiu8310
# Processed user 717 of 744: lygztq
# Processed user 718 of 744: Misaka13514
# Processed user 719 of 744: vincentpanqi
# Processed user 720 of 744: forehalo
# Processed user 721 of 744: XiaoTaoWang
# Processed user 722 of 744: WilberTian
# Processed user 723 of 744: harryhare
# Processed user 724 of 744: hitokoto-osc
# Processed user 725 of 744: rk2900
# Processed user 726 of 744: JavaNoober
# Processed user 727 of 744: bootsrc
# Processed user 728 of 744: black-binary
# Processed user 729 of 744: StevenLiuWen
# Processed user 730 of 744: tabokie
# Processed user 731 of 744: rudeigerc
# Processed user 732 of 744: klboke
# Processed user 733 of 744: eleme
# Processed user 734 of 744: QipengGuo
# Processed user 735 of 744: CraryPrimitiveMan
# Processed user 736 of 744: skygragon
# Processed user 737 of 744: zw76859420
# Processed user 738 of 744: jimexist
# Processed user 739 of 744: windoze
# Processed user 740 of 744: nighca
# Processed user 741 of 744: HiWong
# Processed user 742 of 744: EricGao888
# Processed user 743 of 744: magicbear
# Processed user 744 of 744: tangzx
# Fetching repositories for user 1 of 744: peng-zhihui
# Fetched 59 repositories for peng-zhihui
# Fetching repositories for user 2 of 744: ruanyf
# Fetched 72 repositories for ruanyf
# Fetching repositories for user 3 of 744: phodal
# Fetched 367 repositories for phodal
# Fetching repositories for user 4 of 744: liyupi
# Fetched 82 repositories for liyupi
# Fetching repositories for user 5 of 744: stormzhang
# Fetched 5 repositories for stormzhang
# Fetching repositories for user 6 of 744: Ovilia
# Fetched 65 repositories for Ovilia
# Fetching repositories for user 7 of 744: astaxie
# Fetched 79 repositories for astaxie
# Fetching repositories for user 8 of 744: bailicangdu
# Fetched 22 repositories for bailicangdu
# Fetching repositories for user 9 of 744: PanJiaChen
# Fetched 72 repositories for PanJiaChen
# Fetching repositories for user 10 of 744: YunaiV
# Fetched 83 repositories for YunaiV
# Fetching repositories for user 11 of 744: sofish
# Fetched 43 repositories for sofish
# Fetching repositories for user 12 of 744: dyc87112
# Fetched 61 repositories for dyc87112
# Fetching repositories for user 13 of 744: skyzh
# Fetched 112 repositories for skyzh
# Fetching repositories for user 14 of 744: nihui
# Fetched 180 repositories for nihui
# Fetching repositories for user 15 of 744: oldratlee
# Fetched 48 repositories for oldratlee
# Fetching repositories for user 16 of 744: xufei
# Fetched 40 repositories for xufei
# Fetching repositories for user 17 of 744: amusi
# Fetched 255 repositories for amusi
# Fetching repositories for user 18 of 744: TommyZihao
# Fetched 129 repositories for TommyZihao
# Fetching repositories for user 19 of 744: xuxueli
# Fetched 12 repositories for xuxueli
# Fetching repositories for user 20 of 744: wx-chevalier
# Fetched 150 repositories for wx-chevalier
# Fetching repositories for user 21 of 744: krahets
# Fetched 10 repositories for krahets
# Fetching repositories for user 22 of 744: teddysun
# Fetched 8 repositories for teddysun
# Fetching repositories for user 23 of 744: hellokaton
# Fetched 95 repositories for hellokaton
# Fetching repositories for user 24 of 744: espressif
# Fetched 248 repositories for espressif
# Fetching repositories for user 25 of 744: madeye
# Fetched 39 repositories for madeye
# Fetching repositories for user 26 of 744: hax
# Fetched 186 repositories for hax
# Fetching repositories for user 27 of 744: pissang
# Fetched 95 repositories for pissang
# Fetching repositories for user 28 of 744: kesenhoo
# Fetched 22 repositories for kesenhoo
# Fetching repositories for user 29 of 744: jmzeng1314
# Fetched 67 repositories for jmzeng1314
# Fetching repositories for user 30 of 744: yiminghe
# Fetched 82 repositories for yiminghe
# Fetching repositories for user 31 of 744: code4craft
# Fetched 119 repositories for code4craft
# Fetching repositories for user 32 of 744: lexrus
# Fetched 47 repositories for lexrus
# Fetching repositories for user 33 of 744: casatwy
# Fetched 26 repositories for casatwy
# Fetching repositories for user 34 of 744: xpqiu
# Fetched 1 repositories for xpqiu
# Fetching repositories for user 35 of 744: markzhai
# Fetched 64 repositories for markzhai
# Fetching repositories for user 36 of 744: candycat1992
# Fetched 15 repositories for candycat1992
# Fetching repositories for user 37 of 744: matyhtf
# Fetched 4 repositories for matyhtf
# Fetching repositories for user 38 of 744: Justineo
# Fetched 153 repositories for Justineo
# Fetching repositories for user 39 of 744: gsdios
# Fetched 16 repositories for gsdios
# Fetching repositories for user 40 of 744: binjie09
# Fetched 65 repositories for binjie09
# Fetching repositories for user 41 of 744: GcsSloop
# Fetched 38 repositories for GcsSloop
# Fetching repositories for user 42 of 744: Ewenwan
# Fetched 500 repositories for Ewenwan
# Fetching repositories for user 43 of 744: KittenYang
# Fetched 166 repositories for KittenYang
# Fetching repositories for user 44 of 744: kymjs
# Fetched 33 repositories for kymjs
# Fetching repositories for user 45 of 744: sl1673495
# Fetched 86 repositories for sl1673495
# Fetching repositories for user 46 of 744: vnpy
# Fetched 84 repositories for vnpy
# Fetching repositories for user 47 of 744: formulahendry
# Fetched 95 repositories for formulahendry
# Fetching repositories for user 48 of 744: tiye
# Fetched 167 repositories for tiye
# Fetching repositories for user 49 of 744: Skykai521
# Fetched 29 repositories for Skykai521
# Fetching repositories for user 50 of 744: feiskyer
# Fetched 79 repositories for feiskyer
# Fetching repositories for user 51 of 744: greyli
# Fetched 131 repositories for greyli
# Fetching repositories for user 52 of 744: geektutu
# Fetched 13 repositories for geektutu
# Fetching repositories for user 53 of 744: Lucifier129
# Fetched 145 repositories for Lucifier129
# Fetching repositories for user 54 of 744: archibate
# Fetched 144 repositories for archibate
# Fetching repositories for user 55 of 744: zzz40500
# Fetched 48 repositories for zzz40500
# Fetching repositories for user 56 of 744: VincentWong3
# Fetched 7 repositories for VincentWong3
# Fetching repositories for user 57 of 744: mmin18
# Fetched 9 repositories for mmin18
# Fetching repositories for user 58 of 744: DjangoPeng
# Error fetching repositories for user DjangoPeng page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/DjangoPeng/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for DjangoPeng
# Fetching repositories for user 59 of 744: Vamei
# Error fetching repositories for user Vamei page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/Vamei/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for Vamei
# Fetching repositories for user 60 of 744: wong2
# Error fetching repositories for user wong2 page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/wong2/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for wong2
# Fetching repositories for user 61 of 744: shidenggui
# Error fetching repositories for user shidenggui page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/shidenggui/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for shidenggui
# Fetching repositories for user 62 of 744: bilibili
# Error fetching repositories for user bilibili page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/bilibili/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for bilibili
# Fetching repositories for user 63 of 744: island205
# Error fetching repositories for user island205 page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/island205/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for island205
# Fetching repositories for user 64 of 744: armink
# Error fetching repositories for user armink page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/armink/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for armink
# Fetching repositories for user 65 of 744: igrr
# Error fetching repositories for user igrr page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/igrr/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for igrr
# Fetching repositories for user 66 of 744: xuyisheng
# Error fetching repositories for user xuyisheng page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/xuyisheng/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for xuyisheng
# Fetching repositories for user 67 of 744: MaxwellGengYF
# Error fetching repositories for user MaxwellGengYF page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/MaxwellGengYF/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for MaxwellGengYF
# Fetching repositories for user 68 of 744: iamkun
# Error fetching repositories for user iamkun page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/iamkun/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for iamkun
# Fetching repositories for user 69 of 744: uknowsec
# Error fetching repositories for user uknowsec page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/uknowsec/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for uknowsec
# Fetching repositories for user 70 of 744: davideuler
# Error fetching repositories for user davideuler page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/davideuler/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for davideuler
# Fetching repositories for user 71 of 744: Jannchie
# Error fetching repositories for user Jannchie page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/Jannchie/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for Jannchie
# Fetching repositories for user 72 of 744: ctiao
# Error fetching repositories for user ctiao page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/ctiao/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for ctiao
# Fetching repositories for user 73 of 744: begeekmyfriend
# Error fetching repositories for user begeekmyfriend page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/begeekmyfriend/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for begeekmyfriend
# Fetching repositories for user 74 of 744: kuitos
# Error fetching repositories for user kuitos page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/kuitos/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for kuitos
# Fetching repositories for user 75 of 744: FrozenGene
# Error fetching repositories for user FrozenGene page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/FrozenGene/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for FrozenGene
# Fetching repositories for user 76 of 744: yc9559
# Error fetching repositories for user yc9559 page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/yc9559/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for yc9559
# Fetching repositories for user 77 of 744: qii
# Error fetching repositories for user qii page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/qii/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for qii
# Fetching repositories for user 78 of 744: csvwolf
# Error fetching repositories for user csvwolf page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/csvwolf/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for csvwolf
# Fetching repositories for user 79 of 744: CymChad
# Error fetching repositories for user CymChad page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/CymChad/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for CymChad
# Fetching repositories for user 80 of 744: yisar
# Error fetching repositories for user yisar page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/yisar/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for yisar
# Fetching repositories for user 81 of 744: ihciah
# Error fetching repositories for user ihciah page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/ihciah/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for ihciah
# Fetching repositories for user 82 of 744: electech6
# Error fetching repositories for user electech6 page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/electech6/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for electech6
# Fetching repositories for user 83 of 744: BaronZ88
# Error fetching repositories for user BaronZ88 page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/BaronZ88/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for BaronZ88
# Fetching repositories for user 84 of 744: Charmve
# Error fetching repositories for user Charmve page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/Charmve/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for Charmve
# Fetching repositories for user 85 of 744: XINCGer
# Error fetching repositories for user XINCGer page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/XINCGer/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for XINCGer
# Fetching repositories for user 86 of 744: LeoMobileDeveloper
# Error fetching repositories for user LeoMobileDeveloper page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/LeoMobileDeveloper/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for LeoMobileDeveloper
# Fetching repositories for user 87 of 744: losfair
# Error fetching repositories for user losfair page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/losfair/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for losfair
# Fetching repositories for user 88 of 744: knightliao
# Error fetching repositories for user knightliao page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/knightliao/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for knightliao
# Fetching repositories for user 89 of 744: lychees
# Error fetching repositories for user lychees page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/lychees/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for lychees
# Fetching repositories for user 90 of 744: GoSSIP-SJTU
# Error fetching repositories for user GoSSIP-SJTU page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/GoSSIP-SJTU/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for GoSSIP-SJTU
# Fetching repositories for user 91 of 744: EspressifApp
# Error fetching repositories for user EspressifApp page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/EspressifApp/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for EspressifApp
# Fetching repositories for user 92 of 744: cyfdecyf
# Error fetching repositories for user cyfdecyf page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/cyfdecyf/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for cyfdecyf
# Fetching repositories for user 93 of 744: songquanpeng
# Error fetching repositories for user songquanpeng page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/songquanpeng/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for songquanpeng
# Fetching repositories for user 94 of 744: zombieJ
# Error fetching repositories for user zombieJ page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/zombieJ/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for zombieJ
# Fetching repositories for user 95 of 744: shrekshrek
# Error fetching repositories for user shrekshrek page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/shrekshrek/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for shrekshrek
# Fetching repositories for user 96 of 744: ExpLangcn
# Error fetching repositories for user ExpLangcn page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/ExpLangcn/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for ExpLangcn
# Fetching repositories for user 97 of 744: lightningMan
# Error fetching repositories for user lightningMan page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/lightningMan/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for lightningMan
# Fetching repositories for user 98 of 744: houbb
# Error fetching repositories for user houbb page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/houbb/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for houbb
# Fetching repositories for user 99 of 744: liu21st
# Error fetching repositories for user liu21st page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/liu21st/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for liu21st
# Fetching repositories for user 100 of 744: wnzhang
# Error fetching repositories for user wnzhang page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/wnzhang/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for wnzhang
# Fetching repositories for user 101 of 744: jikeytang
# Error fetching repositories for user jikeytang page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/jikeytang/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for jikeytang
# Fetching repositories for user 102 of 744: xiewenwei
# Error fetching repositories for user xiewenwei page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/xiewenwei/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for xiewenwei
# Fetching repositories for user 103 of 744: zensh
# Error fetching repositories for user zensh page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/zensh/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for zensh
# Fetching repositories for user 104 of 744: cfc4n
# Error fetching repositories for user cfc4n page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/cfc4n/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for cfc4n
# Fetching repositories for user 105 of 744: nobodyiam
# Error fetching repositories for user nobodyiam page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/nobodyiam/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for nobodyiam
# Fetching repositories for user 106 of 744: KeKe-Li
# Error fetching repositories for user KeKe-Li page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/KeKe-Li/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for KeKe-Li
# Fetching repositories for user 107 of 744: journey-ad
# Error fetching repositories for user journey-ad page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/journey-ad/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for journey-ad
# Fetching repositories for user 108 of 744: Jocs
# Error fetching repositories for user Jocs page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/Jocs/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for Jocs
# Fetching repositories for user 109 of 744: mcxtzhang
# Error fetching repositories for user mcxtzhang page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/mcxtzhang/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for mcxtzhang
# Fetching repositories for user 110 of 744: wingjay
# Error fetching repositories for user wingjay page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/wingjay/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for wingjay
# Fetching repositories for user 111 of 744: leeight
# Error fetching repositories for user leeight page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/leeight/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for leeight
# Fetching repositories for user 112 of 744: fordream
# Error fetching repositories for user fordream page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/fordream/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for fordream
# Fetching repositories for user 113 of 744: zhuangbiaowei
# Error fetching repositories for user zhuangbiaowei page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/zhuangbiaowei/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for zhuangbiaowei
# Fetching repositories for user 114 of 744: flyerhzm
# Error fetching repositories for user flyerhzm page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/flyerhzm/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for flyerhzm
# Fetching repositories for user 115 of 744: Becavalier
# Error fetching repositories for user Becavalier page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/Becavalier/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for Becavalier
# Fetching repositories for user 116 of 744: yangxue0827
# ...
# Fetched 0 repositories for zhiqiangxu
# Fetching repositories for user 687 of 744: jasonGeng88
# Error fetching repositories for user jasonGeng88 page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/jasonGeng88/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for jasonGeng88
# Fetching repositories for user 688 of 744: Maxwin-z
# Error fetching repositories for user Maxwin-z page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/Maxwin-z/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for Maxwin-z
# Fetching repositories for user 689 of 744: yongluo2013
# Error fetching repositories for user yongluo2013 page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/yongluo2013/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for yongluo2013
# Fetching repositories for user 690 of 744: liguobao
# Error fetching repositories for user liguobao page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/liguobao/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for liguobao
# Fetching repositories for user 691 of 744: IFmiss
# Error fetching repositories for user IFmiss page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/IFmiss/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for IFmiss
# Fetching repositories for user 692 of 744: OysterQAQ
# Error fetching repositories for user OysterQAQ page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/OysterQAQ/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for OysterQAQ
# Fetching repositories for user 693 of 744: childrentime
# Error fetching repositories for user childrentime page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/childrentime/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for childrentime
# Fetching repositories for user 694 of 744: sillykelvin
# Error fetching repositories for user sillykelvin page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/sillykelvin/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for sillykelvin
# Fetching repositories for user 695 of 744: HillZhang1999
# Error fetching repositories for user HillZhang1999 page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/HillZhang1999/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for HillZhang1999
# Fetching repositories for user 696 of 744: Lancern
# Error fetching repositories for user Lancern page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/Lancern/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for Lancern
# Fetching repositories for user 697 of 744: wolf96
# Error fetching repositories for user wolf96 page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/wolf96/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for wolf96
# Fetching repositories for user 698 of 744: tashaxing
# Error fetching repositories for user tashaxing page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/tashaxing/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for tashaxing
# Fetching repositories for user 699 of 744: worldzhao
# Error fetching repositories for user worldzhao page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/worldzhao/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for worldzhao
# Fetching repositories for user 700 of 744: chenkkkk
# Error fetching repositories for user chenkkkk page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/chenkkkk/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for chenkkkk
# Fetching repositories for user 701 of 744: felixhao
# Error fetching repositories for user felixhao page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/felixhao/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for felixhao
# Fetching repositories for user 702 of 744: liangxiegame
# Error fetching repositories for user liangxiegame page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/liangxiegame/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for liangxiegame
# Fetching repositories for user 703 of 744: soarqin
# Error fetching repositories for user soarqin page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/soarqin/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for soarqin
# Fetching repositories for user 704 of 744: comzyh
# Error fetching repositories for user comzyh page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/comzyh/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for comzyh
# Fetching repositories for user 705 of 744: Bywalks
# Error fetching repositories for user Bywalks page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/Bywalks/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for Bywalks
# Fetching repositories for user 706 of 744: YesianRohn
# Error fetching repositories for user YesianRohn page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/YesianRohn/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for YesianRohn
# Fetching repositories for user 707 of 744: xdd666t
# Error fetching repositories for user xdd666t page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/xdd666t/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for xdd666t
# Fetching repositories for user 708 of 744: wegamekinglc
# Error fetching repositories for user wegamekinglc page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/wegamekinglc/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for wegamekinglc
# Fetching repositories for user 709 of 744: miclle
# Error fetching repositories for user miclle page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/miclle/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for miclle
# Fetching repositories for user 710 of 744: ultmaster
# Error fetching repositories for user ultmaster page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/ultmaster/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for ultmaster
# Fetching repositories for user 711 of 744: shyoshyo
# Error fetching repositories for user shyoshyo page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/shyoshyo/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for shyoshyo
# Fetching repositories for user 712 of 744: waynebaby
# Error fetching repositories for user waynebaby page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/waynebaby/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for waynebaby
# Fetching repositories for user 713 of 744: xw-hu
# Error fetching repositories for user xw-hu page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/xw-hu/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for xw-hu
# Fetching repositories for user 714 of 744: EthanDeng
# Error fetching repositories for user EthanDeng page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/EthanDeng/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for EthanDeng
# Fetching repositories for user 715 of 744: eshengsky
# Error fetching repositories for user eshengsky page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/eshengsky/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for eshengsky
# Fetching repositories for user 716 of 744: qiu8310
# Error fetching repositories for user qiu8310 page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/qiu8310/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for qiu8310
# Fetching repositories for user 717 of 744: lygztq
# Error fetching repositories for user lygztq page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/lygztq/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for lygztq
# Fetching repositories for user 718 of 744: Misaka13514
# Error fetching repositories for user Misaka13514 page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/Misaka13514/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for Misaka13514
# Fetching repositories for user 719 of 744: vincentpanqi
# Error fetching repositories for user vincentpanqi page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/vincentpanqi/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for vincentpanqi
# Fetching repositories for user 720 of 744: forehalo
# Error fetching repositories for user forehalo page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/forehalo/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for forehalo
# Fetching repositories for user 721 of 744: XiaoTaoWang
# Error fetching repositories for user XiaoTaoWang page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/XiaoTaoWang/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for XiaoTaoWang
# Fetching repositories for user 722 of 744: WilberTian
# Error fetching repositories for user WilberTian page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/WilberTian/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for WilberTian
# Fetching repositories for user 723 of 744: harryhare
# Error fetching repositories for user harryhare page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/harryhare/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for harryhare
# Fetching repositories for user 724 of 744: hitokoto-osc
# Error fetching repositories for user hitokoto-osc page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/hitokoto-osc/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for hitokoto-osc
# Fetching repositories for user 725 of 744: rk2900
# Error fetching repositories for user rk2900 page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/rk2900/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for rk2900
# Fetching repositories for user 726 of 744: JavaNoober
# Error fetching repositories for user JavaNoober page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/JavaNoober/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for JavaNoober
# Fetching repositories for user 727 of 744: bootsrc
# Error fetching repositories for user bootsrc page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/bootsrc/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for bootsrc
# Fetching repositories for user 728 of 744: black-binary
# Error fetching repositories for user black-binary page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/black-binary/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for black-binary
# Fetching repositories for user 729 of 744: StevenLiuWen
# Error fetching repositories for user StevenLiuWen page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/StevenLiuWen/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for StevenLiuWen
# Fetching repositories for user 730 of 744: tabokie
# Error fetching repositories for user tabokie page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/tabokie/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for tabokie
# Fetching repositories for user 731 of 744: rudeigerc
# Error fetching repositories for user rudeigerc page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/rudeigerc/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for rudeigerc
# Fetching repositories for user 732 of 744: klboke
# Error fetching repositories for user klboke page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/klboke/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for klboke
# Fetching repositories for user 733 of 744: eleme
# Error fetching repositories for user eleme page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/eleme/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for eleme
# Fetching repositories for user 734 of 744: QipengGuo
# Error fetching repositories for user QipengGuo page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/QipengGuo/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for QipengGuo
# Fetching repositories for user 735 of 744: CraryPrimitiveMan
# Error fetching repositories for user CraryPrimitiveMan page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/CraryPrimitiveMan/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for CraryPrimitiveMan
# Fetching repositories for user 736 of 744: skygragon
# Error fetching repositories for user skygragon page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/skygragon/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for skygragon
# Fetching repositories for user 737 of 744: zw76859420
# Error fetching repositories for user zw76859420 page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/zw76859420/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for zw76859420
# Fetching repositories for user 738 of 744: jimexist
# Error fetching repositories for user jimexist page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/jimexist/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for jimexist
# Fetching repositories for user 739 of 744: windoze
# Error fetching repositories for user windoze page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/windoze/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for windoze
# Fetching repositories for user 740 of 744: nighca
# Error fetching repositories for user nighca page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/nighca/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for nighca
# Fetching repositories for user 741 of 744: HiWong
# Error fetching repositories for user HiWong page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/HiWong/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for HiWong
# Fetching repositories for user 742 of 744: EricGao888
# Error fetching repositories for user EricGao888 page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/EricGao888/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for EricGao888
# Fetching repositories for user 743 of 744: magicbear
# Error fetching repositories for user magicbear page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/magicbear/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for magicbear
# Fetching repositories for user 744 of 744: tangzx
# Error fetching repositories for user tangzx page 1: 403 Client Error: Forbidden for url: https://api.github.com/users/tangzx/repos?sort=pushed&direction=desc&page=1&per_page=100
# Fetched 0 repositories for tangzx
#
# Data scraping completed successfully!
# Total users scraped: 744
# Total repositories scraped: 5072
